# %% [markdown]
# <a href="https://colab.research.google.com/github/keshav-hl/Data-Science-Baasics/blob/main/Normal_Distribution_and_Z_Score_math3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Standard Deviation
#
# ---

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/height and gender(in).csv')
df.head()
# Out:
#    Gender      Height
# 0    Male  153.278361
# 1    Male  199.333636
# 2  Female  176.137288
# 3  Female  168.847337
# 4    Male  176.453651

# %%
df.describe()
# Out:
#            Height
# count  100.000000
# mean   174.023989
# std     14.740397
# min    150.887126
# 25%    160.893515
# 50%    172.218430
# 75%    185.551391
# max    199.736873

# %%
sns.histplot(df.Height, kde=True)
# Out:
# <Axes: xlabel='Height', ylabel='Count'>

# %%
mean = df.Height.mean()
mean
# Out:
# np.float64(174.02398871699995)

# %%
std = df.Height.std()
std
# Out:
# 14.740397119318414

# %%
mean - 3 * std
# Out:
# np.float64(129.80279735904472)

# %%
mean + 3 * std
# Out:
# np.float64(218.2451800749552)

# %%
df [df.Height < 129.80]
# Out:
# Empty DataFrame
# Columns: [Gender, Height]
# Index: []

# %%
df [df.Height > 218.24]
# Out:
# Empty DataFrame
# Columns: [Gender, Height]
# Index: []

# %%
df[(df.Height < 129.80) | (df.Height > 218.24)]
# Out:
# Empty DataFrame
# Columns: [Gender, Height]
# Index: []

# %%
df_no_outlayer = df[(df.Height > 129.80) & (df.Height < 218.24)]
df_no_outlayer.shape
# Out:
# (100, 2)

# %% [markdown]
# Z-Score
#
# ---

# %%
df.head()
# Out:
#    Gender      Height
# 0    Male  153.278361
# 1    Male  199.333636
# 2  Female  176.137288
# 3  Female  168.847337
# 4    Male  176.453651

# %%
df['zscore'] = (df.Height-df.Height.mean())/df.Height.std()
df.head()
# Out:
#    Gender      Height    zscore
# 0    Male  153.278361 -1.407399
# 1    Male  199.333636  1.717026
# 2  Female  176.137288  0.143368
# 3  Female  168.847337 -0.351188
# 4    Male  176.453651  0.164830

# %%
df.Height.mean()
# Out:
# np.float64(174.02398871699995)

# %%
df.Height.std()
# Out:
# 14.740397119318414

# %%
(153.278361 - 174.02398871699995 ) / 14.740397119318414
# Out:
# -1.4073995123110514

# %%
df[df.zscore < -3]
# Out:
# Empty DataFrame
# Columns: [Gender, Height, zscore]
# Index: []

# %%
df[df.zscore > 3]
# Out:
# Empty DataFrame
# Columns: [Gender, Height, zscore]
# Index: []

# %%
df[(df.zscore < -3) | (df.zscore > 3)]
# Out:
# Empty DataFrame
# Columns: [Gender, Height, zscore]
# Index: []

# %%
df_no_outlayer = df[(df.zscore > -3) & (df.zscore < 3)]
df_no_outlayer.shape
# Out:
# (100, 3)
